# %% [markdown]
# <a href="https://colab.research.google.com/github/osmyildiz/data_analysis/blob/master/DV_capstone_student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to **"Bike Demand Visualization Project"** which is the capstone project of Data Visualization Lessons . As you know recently, free or affordable access to bicycles has been provided for short-distance trips in an urban area as an alternative to motorized public transport or private vehicles. Thus, it is aimed to reduce traffic congestion, noise and air pollution.
#
# The aim of this project is to reveal the current patterns in the data by showing the historical data of London bike shares with visualization tools.
#
# This will allow us to X-ray the data as part of the EDA process before setting up a machine learning model.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # #Determines
#
#
#
# #### Features
#
# - timestamp - timestamp field for grouping the data
# - cnt - the count of a new bike shares
# - t1 - real temperature in C
# - t2 - temperature in C “feels like”
# - hum - humidity in percentage
# - wind_speed - wind speed in km/h
# - weather_code - category of the weather
# - is_holiday - boolean field - 1 holiday / 0 non holiday
# - is_weekend - boolean field - 1 if the day is weekend
# - season - category field meteorological seasons: 0-spring ; 1-summer; 2-fall; 3-winter.
#
# **"weather_code" category description:**
# * 1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity
# * 2 = scattered clouds / few clouds
# * 3 = Broken clouds
# * 4 = Cloudy
# * 7 = Rain/ light Rain shower/ Light rain
# * 10 = rain with thunderstorm
# * 26 = snowfall
# * 94 = Freezing Fog
# ---
#
# Initially, the task of discovering data will be waiting for you as always. Recognize features, detect missing values, outliers etc.  Review the data from various angles in different time breakdowns. For example, visualize the distribution of bike shares by day of the week. With this graph, you will be able to easily observe and make inferences how people's behavior changes daily. Likewise, you can make hourly, monthly, seasonally etc. analyzes. In addition, you can analyze correlation of variables with a heatmap.

# %% [markdown]
# # Tasks

# %% [markdown]
# ### 1.Import libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
from pylab import rcParams
sns.set_style("darkgrid")

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 2.Read dataset

# %%
df0=pd.read_csv("/content/drive/MyDrive/datascience/store_sharing.csv")

# %%
df=df0.copy()
df
# Out:
#                  timestamp   cnt   t1  ...  is_holiday  is_weekend  season
# 0      2015-01-04 00:00:00   182  3.0  ...         0.0         1.0     3.0
# 1      2015-01-04 01:00:00   138  3.0  ...         0.0         1.0     3.0
# 2      2015-01-04 02:00:00   134  2.5  ...         0.0         1.0     3.0
# 3      2015-01-04 03:00:00    72  2.0  ...         0.0         1.0     3.0
# 4      2015-01-04 04:00:00    47  2.0  ...         0.0         1.0     3.0
# ...                    ...   ...  ...  ...         ...         ...     ...
# 17409  2017-01-03 19:00:00  1042  5.0  ...         0.0         0.0     3.0
# 17410  2017-01-03 20:00:00   541  5.0  ...         0.0         0.0     3.0
# 17411  2017-01-03 21:00:00   337  5.5  ...         0.0         0.0     3.0
# 17412  2017-01-03 22:00:00   224  5.5  ...         0.0         0.0     3.0
# 17413  2017-01-03 23:00:00   139  5.0  ...         0.0         0.0     3.0
#
# [17414 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#                 cnt            t1  ...    is_weekend        season
# count  17414.000000  17414.000000  ...  17414.000000  17414.000000
# mean    1143.101642     12.468091  ...      0.285403      1.492075
# std     1085.108068      5.571818  ...      0.451619      1.118911
# min        0.000000     -1.500000  ...      0.000000      0.000000
# 25%      257.000000      8.000000  ...      0.000000      0.000000
# 50%      844.000000     12.500000  ...      0.000000      1.000000
# 75%     1671.750000     16.000000  ...      1.000000      2.000000
# max     7860.000000     34.000000  ...      1.000000      3.000000
#
# [8 rows x 9 columns]

# %% [markdown]
# ### 3.Check missing values and if there are any dublicate rows or not.

# %%
df.isnull().sum()
# Out:
# timestamp       0
# cnt             0
# t1              0
# t2              0
# hum             0
# wind_speed      0
# weather_code    0
# is_holiday      0
# is_weekend      0
# season          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated().value_counts()
# Out:
# False    17414
# dtype: int64

# %%
# Out:
# timestamp       0
# cnt             0
# t1              0
# t2              0
# hum             0
# wind_speed      0
# weather_code    0
# is_holiday      0
# is_weekend      0
# season          0
# dtype: int64

# %% [markdown]
# ### 4.Plot the distribution of various discrete features on (Season, haliday, weekend and weathercode)

# %%
sns.countplot(df.season)

# %%
sns.countplot("is_holiday", data=df)

# %%
# is_weekend
sns.countplot("is_weekend", data=df)

# %%
# weather_code
sns.countplot(df["weather_code"])

# %% [markdown]
# ### 5.Look at the data type of each variable, transform `timestamp` in type, and set it as index.

# %%
df.columns
# Out:
# Index(['timestamp', 'cnt', 't1', 't2', 'hum', 'wind_speed', 'weather_code',
#        'is_holiday', 'is_weekend', 'season'],
#       dtype='object')

# %%
df["timestamp"] = pd.to_datetime(df["timestamp"])
df["timestamp"]
# Out:
# 0       2015-01-04 00:00:00
# 1       2015-01-04 01:00:00
# 2       2015-01-04 02:00:00
# 3       2015-01-04 03:00:00
# 4       2015-01-04 04:00:00
#                 ...
# 17409   2017-01-03 19:00:00
# 17410   2017-01-03 20:00:00
# 17411   2017-01-03 21:00:00
# 17412   2017-01-03 22:00:00
# 17413   2017-01-03 23:00:00
# Name: timestamp, Length: 17414, dtype: datetime64[ns]

# %%
df.set_index("timestamp", inplace=True)

# %%
df.head()
# Out:
#                      cnt   t1   t2  ...  is_holiday  is_weekend  season
# timestamp                           ...
# 2015-01-04 00:00:00  182  3.0  2.0  ...         0.0         1.0     3.0
# 2015-01-04 01:00:00  138  3.0  2.5  ...         0.0         1.0     3.0
# 2015-01-04 02:00:00  134  2.5  2.5  ...         0.0         1.0     3.0
# 2015-01-04 03:00:00   72  2.0  2.0  ...         0.0         1.0     3.0
# 2015-01-04 04:00:00   47  2.0  0.0  ...         0.0         1.0     3.0
#
# [5 rows x 9 columns]

# %% [markdown]
# - Tam 2 yillik bir timestamp var. `year, month, day_of_month, day_of_week, hour` bilgilerini alarak feature engineering yapalim

# %% [markdown]
# ### 6.Make feature engineering. Extract new columns (day of the week, day of the month, hour, month, season, year etc.)

# %% [markdown]
# you can use strftime('%Y-%m') for year_mount

# %%
df.index
# Out:
# DatetimeIndex(['2015-01-04 00:00:00', '2015-01-04 01:00:00',
#                '2015-01-04 02:00:00', '2015-01-04 03:00:00',
#                '2015-01-04 04:00:00', '2015-01-04 05:00:00',
#                '2015-01-04 06:00:00', '2015-01-04 07:00:00',
#                '2015-01-04 08:00:00', '2015-01-04 09:00:00',
#                ...
#                '2017-01-03 14:00:00', '2017-01-03 15:00:00',
#                '2017-01-03 16:00:00', '2017-01-03 17:00:00',
#                '2017-01-03 18:00:00', '2017-01-03 19:00:00',
#                '2017-01-03 20:00:00', '2017-01-03 21:00:00',
#                '2017-01-03 22:00:00', '2017-01-03 23:00:00'],
#               dtype='datetime64[ns]', name='timestamp', length=17414, freq=None)

# %%
df.head()
# Out:
#                      cnt   t1   t2  ...  is_holiday  is_weekend  season
# timestamp                           ...
# 2015-01-04 00:00:00  182  3.0  2.0  ...         0.0         1.0     3.0
# 2015-01-04 01:00:00  138  3.0  2.5  ...         0.0         1.0     3.0
# 2015-01-04 02:00:00  134  2.5  2.5  ...         0.0         1.0     3.0
# 2015-01-04 03:00:00   72  2.0  2.0  ...         0.0         1.0     3.0
# 2015-01-04 04:00:00   47  2.0  0.0  ...         0.0         1.0     3.0
#
# [5 rows x 9 columns]

# %%
# day of the week, day of the month, hour, month, season, year
df["month"] = df.index.month
df["day_of_month"] = df.index.day
df["day_of_week"] = df.index.dayofweek
df["hour"] = df.index.hour
df["year_month"] = df.index.strftime('%Y-%m')

# %%
df.head()
# Out:
#                      cnt   t1   t2  ...  day_of_week  hour  year_month
# timestamp                           ...
# 2015-01-04 00:00:00  182  3.0  2.0  ...            6     0     2015-01
# 2015-01-04 01:00:00  138  3.0  2.5  ...            6     1     2015-01
# 2015-01-04 02:00:00  134  2.5  2.5  ...            6     2     2015-01
# 2015-01-04 03:00:00   72  2.0  2.0  ...            6     3     2015-01
# 2015-01-04 04:00:00   47  2.0  0.0  ...            6     4     2015-01
#
# [5 rows x 15 columns]

# %% [markdown]
# ### 7.Visualize the correlation with a heatmap

# %% [markdown]
# Hep sevmisimdir renkleri:)

# %%
# for all variables 
plt.figure(figsize = (15, 10))
sns.heatmap(df.corr(), cmap ="coolwarm",  annot = True)

# %%
# for the target variable
plt.figure(figsize = (3, 10))
sns.heatmap(df.corr()[["cnt"]].sort_values(by = "cnt", ascending=False), cmap ="inferno",  annot = True)

# %% [markdown]
# ### 8. Visualize the correlation of the target variable and the other features with barplot

# %%
cor = df.corr()[["cnt"]].sort_values(by = "cnt", ascending=False)
cor
# Out:
#                    cnt
# cnt           1.000000
# t1            0.388798
# t2            0.369035
# hour          0.324423
# wind_speed    0.116295
# month         0.063757
# year          0.010046
# day_of_month -0.017887
# is_holiday   -0.051698
# day_of_week  -0.068688
# is_weekend   -0.096499
# season       -0.116180
# weather_code -0.166633
# hum          -0.462901

# %%
#with pandas
plt.figure(figsize = (12,6))
sns.barplot(y=cor.sort_values("cnt",ascending=True).index,x=cor.sort_values("cnt",ascending=True)['cnt'],color="Navy")
plt.show()

# %% [markdown]
# ### 9.Plot bike shares over time use lineplot

# %%
df.head()
# Out:
#                      cnt   t1   t2  ...  day_of_week  hour  year_month
# timestamp                           ...
# 2015-01-04 00:00:00  182  3.0  2.0  ...            6     0     2015-01
# 2015-01-04 01:00:00  138  3.0  2.5  ...            6     1     2015-01
# 2015-01-04 02:00:00  134  2.5  2.5  ...            6     2     2015-01
# 2015-01-04 03:00:00   72  2.0  2.0  ...            6     3     2015-01
# 2015-01-04 04:00:00   47  2.0  0.0  ...            6     4     2015-01
#
# [5 rows x 15 columns]

# %%
plt.figure(figsize = (15,6))

sns.lineplot(x = df.index, y = df.cnt)

# %% [markdown]
# ### 10.Plot bike shares by months and year_of_month (use lineplot, pointplot, barplot)

# %%
# with lineplot
plt.figure(figsize = (15,4))

sns.lineplot(x = df.year_month, y = df.cnt, ci = None)
plt.xticks(rotation = 90);

# %%
# with lineplot
plt.figure(figsize = (12,6))
sns.lineplot(x = df.month, y = df.cnt)

# %%
# with pointplot
plt.figure(figsize = (15,5))
sns.pointplot(x = df.month, y = df.cnt)

# %%
plt.figure(figsize = (12,6))

sns.barplot(x = df.month, y = df.cnt);

# %% [markdown]
# ### 11.Plot bike shares by hours on (holidays, weekend, season)

# %%
# with lineplot (*whether it is a holiday or not*)
plt.figure(figsize = (18,5))

sns.lineplot(x = df.hour, y = df.cnt, hue = df.is_holiday);

# %%
# with lineplot (*You may want to see seasonal breakdowns*)
plt.figure(figsize = (15,6))

sns.lineplot(x = df.hour, y = df.cnt, hue = df.season);

# %%
# with pointplot
fig, ax = plt.subplots(4, 1, figsize = (20, 15))

sns.pointplot(ax=ax[0],x = df.hour, y = df.cnt )
sns.pointplot(ax = ax[1], x = df.hour, y = df.cnt, hue = df.is_holiday )
sns.pointplot(ax = ax[2],x = df.hour, y = df.cnt, hue = df.is_weekend)
sns.pointplot(ax = ax[3],x = df.hour, y = df.cnt, hue = df.season)
plt.tight_layout();

# %% [markdown]
# ### 12.Plot bike shares by day of week
# - You may want to see whether it is a holiday or not

# %%
plt.figure(figsize=(8,6))

sns.barplot(x = df.day_of_week, y = df.cnt, hue = df["is_weekend"])

# %%
fig, ax = plt.subplots(2, 1, figsize = (20, 8))

sns.pointplot(x = df.day_of_week, y = df.cnt, ax=ax[0])
sns.pointplot(x = df.day_of_week, y = df.cnt, hue = df.season, ax = ax[1]);

# %% [markdown]
# ### 13.Plot bike shares by day of month

# %%
pd.DataFrame(df.groupby("day_of_month")["cnt"].mean()).astype("int").T
# Out:
# day_of_month    1     2     3     4     5   ...    27    28    29    30   31
# cnt           1077  1088  1127  1144  1140  ...  1130  1062  1079  1156  968
#
# [1 rows x 31 columns]

# %%
#with lineplot
plt.figure(figsize=(15, 6))

sns.lineplot(x = df.day_of_month, y = df.cnt);
pd.DataFrame(df.groupby("day_of_month")["cnt"].mean()).round().astype("int").T
# Out:
# day_of_month    1     2     3     4     5   ...    27    28    29    30   31
# cnt           1077  1088  1128  1144  1141  ...  1131  1063  1080  1156  968
#
# [1 rows x 31 columns]

# %% [markdown]
# ### 14.Plot bike shares by year
# ### Plot bike shares on holidays by seasons

# %%
# with barplot

plt.figure(figsize=(8,6))
sns.barplot(x=df.year, y=df.cnt)

# %%
# with barplot
plt.figure(figsize=(10,6))

sns.barplot(x=df[df["is_holiday"] == 1]["season"], y=df.cnt)

# %% [markdown]
# ### 15.Visualize the distribution of bike shares by weekday/weekend with piechart and barplot

# %%
df["is_weekend"].value_counts()
# Out:
# 0.0    12444
# 1.0     4970
# Name: is_weekend, dtype: int64

# %%
labels =  ['weekend', 'weekday']
values = df["is_weekend"].value_counts()

fig, ax = plt.subplots(figsize=(5,5))
ax.pie(values, labels=labels, autopct='%1.1f%%') 

plt.show()

# %%
df["is_weekend"].value_counts().sum()
# Out:
# 17414

# %%
sum = df["is_weekend"].value_counts().sum()
sum
# Out:
# 17414

# %%
fig, ax = plt.subplots(figsize=(7,5))
sum = df["is_weekend"].value_counts().sum()
ax = sns.countplot(x=df.is_weekend)
for p in ax.patches:
  ax.annotate("%" + str(round(p.get_height()/sum*100,1)) + "-" + str(p.get_height()), (p.get_x() + 0.2, p.get_height()+200), fontsize = 12);

# %% [markdown]
# ### 16.Plot the distribution of weather code by seasons

# %%
df.weather_code.value_counts()
# Out:
# 1.0     6150
# 2.0     4034
# 3.0     3551
# 7.0     2141
# 4.0     1464
# 26.0      60
# 10.0      14
# Name: weather_code, dtype: int64

# %%
df.cnt.describe()
# Out:
# count    17414.000000
# mean      1143.101642
# std       1085.108068
# min          0.000000
# 25%        257.000000
# 50%        844.000000
# 75%       1671.750000
# max       7860.000000
# Name: cnt, dtype: float64

# %%
sns.countplot(x=df.weather_code.sort_values());

# %%
sns.catplot(x="weather_code", data=df, col = "season", kind= "count");

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
